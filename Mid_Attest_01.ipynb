# %% [markdown]
# <a href="https://colab.research.google.com/github/peter1313st/inno_repo/blob/main/Mid_Attest_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hi')
# Out:
# hi

# %% [markdown]
# # Mid. Attest. 1 Notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
###

# %% [markdown]
# #Connect Colab & Git repo

# %%
git_url_tk = 'https://raw.githubusercontent.com/peter1313st/inno_repo/main/mid_att_1_dataset/dataset_tk.csv'
tk1 = pd.read_csv(git_url)
tk1.rename(columns={"Unnamed: 0":"Date"},inplace=True)
tk1['Date']=pd.to_datetime(tk1["Date"],dayfirst=True)
tk1["year"]=tk1["Date"].dt.year
tk1["month"]=tk1["Date"].dt.month
tk1["day"]=tk1["Date"].dt.day
tk1.drop(["Date"],axis=1,inplace=True)
tk1.head(3)
# Out:
#    Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand    HP   J&K  \
# 0   119.9    130.3      234.1   85.8  313.9         40.7  30.0  52.5
# 1   121.9    133.5      240.2   85.5  311.8         39.3  30.1  54.1
# 2   118.8    128.2      239.8   83.5  320.7         38.1  30.1  53.2
#
#    Chandigarh  Chhattisgarh  ...  Arunachal Pradesh  Assam  Manipur  \
# 0         5.0          78.7  ...                2.1   21.7      2.7
# 1         4.9          78.8  ...                2.2   23.4      2.4
# 2         4.8          74.8  ...                2.2   21.7      2.4
#
#    Meghalaya  Mizoram  Nagaland  Tripura  year  month  day
# 0        6.1      1.9       2.2      3.4  2019      1    2
# 1        6.5      1.8       2.2      3.6  2019      1    3
# 2        6.3      1.7       2.2      3.5  2019      1    4
#
# [3 rows x 36 columns]

# %%
tk1.describe()
# Out:
#            Punjab     Haryana   Rajasthan       Delhi          UP  \
# count  503.000000  503.000000  503.000000  503.000000  503.000000
# mean   141.145527  138.333598  218.443340   83.380716  314.036382
# std     56.977361   38.106593   27.421615   25.915357   66.516960
# min     56.100000   64.800000  105.800000   41.800000  186.800000
# 25%    104.000000  114.800000  205.800000   63.500000  263.650000
# 50%    118.300000  126.800000  222.900000   72.700000  290.000000
# 75%    162.500000  158.100000  237.600000  105.800000  370.550000
# max    300.000000  237.200000  278.000000  147.100000  471.800000
#
#        Uttarakhand          HP         J&K  Chandigarh  Chhattisgarh  ...  \
# count   503.000000  503.000000  503.000000  503.000000    503.000000  ...
# mean     36.157058   26.568191   44.264016    4.141551     83.877137  ...
# std       6.705108    4.807040    4.769391    1.143422     10.130427  ...
# min      16.800000   11.800000   17.800000    2.200000     37.200000  ...
# ...

# %%
git_url_longd='https://raw.githubusercontent.com/peter1313st/inno_repo/main/mid_att_1_dataset/long_data_.csv'
lng1=pd.read_csv(git_url_longd)
lng1['Dates']=pd.to_datetime(lng1["Dates"],dayfirst=True)
lng1["year"]=lng1["Dates"].dt.year
lng1["month"]=lng1["Dates"].dt.month
lng1["day"]=lng1["Dates"].dt.day
lng1.drop(["latitude","longitude","Dates"],axis=1,inplace=True)
lng1.head(3)
# Out:
#       States Regions  Usage  year  month  day
# 0     Punjab      NR  119.9  2019      1    2
# 1    Haryana      NR  130.3  2019      1    2
# 2  Rajasthan      NR  234.1  2019      1    2

# %%
lng1.describe()
# Out:
#               Usage          year         month           day
# count  16599.000000  16599.000000  16599.000000  16599.000000
# mean     103.001862   2019.286282      5.910537     15.318091
# std      116.044056      0.452037      3.461615      9.056657
# min        0.300000   2019.000000      1.000000      1.000000
# 25%        6.700000   2019.000000      3.000000      6.000000
# 50%       64.400000   2019.000000      5.000000     16.000000
# 75%      173.900000   2020.000000      9.000000     23.000000
# max      522.100000   2020.000000     12.000000     31.000000

# %% [markdown]
# 1.Какой регион потребляет максимальную и минимальную мощность в год?

# %%
c=dict()
for i in (lng1.Regions.unique()):
    a=lng1[(lng1["Regions"]==i)&(lng1["year"]==2020)]
    b=a.Usage.sum()
    c.update({i:b})

print(c)

d=dict()
for i in (lng1.Regions.unique()):
    a=lng1[(lng1["Regions"]==i)&(lng1["year"]==2019)]
    b=a.Usage.sum()
    d.update({i:b})

print(d)
# Out:
# {'NR': 147559.8, 'WR': 155089.3, 'SR': 137883.39999999997, 'ER': 46799.4, 'NER': 6190.7}
# {'NR': 358694.8, 'WR': 385280.5, 'SR': 338795.20000000007, 'ER': 117915.1, 'NER': 15519.7}

# %%
print(f" максимум потребленной мощности в 2020 было {c[max(c)]} по {max(c)} региону\n минимум потребленной мощности в 2020 было {c[min(c)]} по {min(c)} региону  ")
print(f" максимум потребленной мощности в 2019 было {d[max(d)]} по {max(d)} региону\n минимум потребленной мощности в 2019 было {d[min(d)]} по {min(d)} региону  ")
# Out:
#  максимум потребленной мощности в 2020 было 155089.3 по WR региону
#  минимум потребленной мощности в 2020 было 46799.4 по ER региону
#  максимум потребленной мощности в 2019 было 385280.5 по WR региону
#  минимум потребленной мощности в 2019 было 117915.1 по ER региону

# %%
#visualisation
table1=pd.DataFrame.from_dict(c,orient="index")
table2=pd.DataFrame.from_dict(d,orient="index")
#
table1.rename(columns={0:"total usages (2020)"},inplace=True)
table2.rename(columns={0:"total usages (2019)"},inplace=True)

# %%
table1.head(2)
# Out:
#     total usages (2020)
# NR             147559.8
# WR             155089.3

# %%
table2.head(2)
# Out:
#     total usages (2019)
# NR             358694.8
# WR             385280.5

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="total usages (2020)",y=table1.index,data=table1)
# Out:
# <Axes: xlabel='total usages (2020)'>

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="total usages (2019)",y=table2.index,data=table2)
# Out:
# <Axes: xlabel='total usages (2019)'>

# %% [markdown]
# 3.Топ-10 штатов, которые потребляют максимальную мощность в год.

# %%
# print("***************2020****************")
usage2020=dict()
for i in (lng1.States.unique()):
    a=lng1[(lng1["States"]==i)&(lng1["year"]==2020)]
    b=a.Usage.sum()
    usage2020.update({i:b})
print(usage2020)
# print("***************2019****************")
usage2019=dict()
for i in (lng1.States.unique()):
    a=lng1[(lng1["States"]==i)&(lng1["year"]==2019)]
    b=a.Usage.sum()
    usage2019.update({i:b})
print(usage2019)
# Out:
# {'Punjab': 21360.5, 'Haryana': 20586.800000000003, 'Rajasthan': 31738.199999999997, 'Delhi': 12482.2, 'UP': 45270.4, 'Uttarakhand': 5288.4, 'HP': 3873.0, 'J&K': 6349.5, 'Chandigarh': 610.8, 'Chhattisgarh': 12010.300000000001, 'Gujarat': 47131.5, 'MP': 29791.800000000003, 'Maharashtra': 62163.1, 'Goa': 1573.4, 'DNH': 2419.2, 'Andhra Pradesh': 25507.399999999998, 'Telangana': 26615.7, 'Karnataka': 29588.800000000003, 'Kerala': 10514.599999999999, 'Tamil Nadu': 44551.3, 'Pondy': 1105.6, 'Bihar': 11821.3, 'Jharkhand': 3387.3, 'Odisha': 11507.1, 'West Bengal': 19901.5, 'Sikkim': 182.20000000000002, 'Arunachal Pradesh': 306.90000000000003, 'Assam': 3575.5, 'Manipur': 360.20000000000005, 'Meghalaya': 820.7, 'Mizoram': 244.0, 'Nagaland': 310.90000000000003, 'Tripura': 572.5}
# ...

# %%
table3=pd.DataFrame.from_dict(usage2020,orient="index")
table4=pd.DataFrame.from_dict(usage2019,orient="index")

# %%
table3.rename(columns={0:'tot. usage in 2020'},inplace=True)
table4.rename(columns={0:'tot. usage in 2019'},inplace=True)

# %%
table3.sort_values(by=['tot. usage in 2020'],ascending=False,inplace=True)
table4.sort_values(by=['tot. usage in 2019'],ascending=False,inplace=True)

# %%
print('Топ 10 штатов, потребляющих макс.мощность в 2020')
table3.head(10)
# Out:
# Топ 10 штатов, потребляющих макс.мощность в 2020
#                 tot. usage in 2020
# Maharashtra                62163.1
# Gujarat                    47131.5
# UP                         45270.4
# Tamil Nadu                 44551.3
# Rajasthan                  31738.2
# MP                         29791.8
# Karnataka                  29588.8
# Telangana                  26615.7
# Andhra Pradesh             25507.4
# Punjab                     21360.5

# %%
print('Топ 10 штатов, потребляющих макс.мощность в 2019')
table4.head(10)
# Out:
# Топ 10 штатов, потребляющих макс.мощность в 2019
#                 tot. usage in 2019
# Maharashtra               154916.7
# Gujarat                   115357.4
# UP                        112689.9
# Tamil Nadu                106720.2
# Rajasthan                  78138.8
# MP                         74974.6
# Karnataka                  73076.9
# Telangana                  67449.6
# Andhra Pradesh             63097.0
# West Bengal                49868.7

# %%
#visualisation
table5=table4.head(10)
plt.figure(figsize=(15, 5))
sns.barplot(y="tot. usage in 2019",x=table5.index,data=table5)
print("Топ 10 штатов по потреблению мощности в 2019")
# Out:
# Топ 10 штатов по потреблению мощности в 2019

# %%
table6=table3.head(10)
plt.figure(figsize=(15, 5))
sns.barplot(y="tot. usage in 2020",x=table6.index,data=table6)
print("Топ 10 штатов по потреблению мощности в 2020")
# Out:
# Топ 10 штатов по потреблению мощности в 2020

# %% [markdown]
# 4. Топ-10 штатов, которые потребляют меньше всего электроэнергии в год.

# %%
print('Топ 10 штатов, которые потребили меньше всего электроэнергии в 2020')
table7=table3.tail(10)
table7
# Out:
# Топ 10 штатов, которые потребили меньше всего электроэнергии в 2020
#                    tot. usage in 2020
# Goa                            1573.4
# Pondy                          1105.6
# Meghalaya                       820.7
# Chandigarh                      610.8
# Tripura                         572.5
# Manipur                         360.2
# Nagaland                        310.9
# Arunachal Pradesh               306.9
# Mizoram                         244.0
# Sikkim                          182.2

# %%
print('Топ 10 штатов, которые потребили меньше всего электроэнергии в 2019')
table8=table4.tail(10)
table8
# Out:
# Топ 10 штатов, которые потребили меньше всего электроэнергии в 2019
#                    tot. usage in 2019
# Goa                            4006.5
# Pondy                          2653.3
# Meghalaya                      2018.1
# Tripura                        1482.5
# Chandigarh                     1472.4
# Manipur                         894.6
# Nagaland                        776.8
# Arunachal Pradesh               754.0
# Mizoram                         614.3
# Sikkim                          466.4

# %%
plt.figure(figsize=(15, 5))
sns.barplot(y="tot. usage in 2019",x=table8.index,data=table8)
print('Топ 10 штатов, которые потребили меньше всего электроэнергии в 2019')
# Out:
# Топ 10 штатов, которые потребили меньше всего электроэнергии в 2019

# %%
plt.figure(figsize=(15, 5))
sns.barplot(y="tot. usage in 2020",x=table7.index,data=table7)
print('Топ 10 штатов, которые потребили меньше всего электроэнергии в 2020')
# Out:
# Топ 10 штатов, которые потребили меньше всего электроэнергии в 2020

# %% [markdown]
# 5. В какие месяцы наблюдается рост потребления?

# %%
dict2019=dict()
for i in range(1,13):
    m=lng1[(lng1["month"]==i)&(lng1["year"]==2019)]
    n=m["Usage"].sum()
    dict2019.update({i:n})
dict2020=dict()
for i in range(1,13):
    m=lng1[(lng1["month"]==i)&(lng1["year"]==2020)]
    n=m["Usage"].sum()
    dict2020.update({i:n})

# %%
month=["jan","feb",'mar',"apr","may","jun","jul","aug","sep","oct","nov","dec"]

# %%
list1=list(dict2019.values())
list2=list(dict2020.values())

# %%
A=max(list1)
B=list1.index(A)
C=month[B]
x=max(list2)
y=list2.index(x)
z=month[y]

# %%
print(f"максимальный рост потребления приходится на месяц {C} 2019")
print(f"максимальный рост потребления приходится на месяц {z} 2020")
# Out:
# максимальный рост потребления приходится на месяц jul 2019
# максимальный рост потребления приходится на месяц jan 2020

# %%
#visualization
plt.figure(figsize = (15, 5))
plt.bar(month,list1,width = 0.4)

plt.ylabel("Потребление")
plt.xlabel("месяц")
plt.title("Макс. рост потребления в 2019")
plt.show()

# %%
#visualization
plt.figure(figsize = (15, 5))
plt.bar(month,list2,width = 0.4)

plt.ylabel("Потребление")
plt.xlabel("месяц")
plt.title("Макс. рост потребления в 2020")
plt.show()

# %% [markdown]
# 6. В какие месяцы наблюдается снижение потребления?

# %%
a=min(list1)
b=list1.index(a)
c=month[b]
X=min(list2)
Y=list2.index(X)
Z=month[Y]
print(f"мин. рост потребления приходится на месяц {c} 2019")
print(f"мин. рост потребления приходится на месяц {Z} 2020")
# Out:
# мин. рост потребления приходится на месяц feb 2019
# мин. рост потребления приходится на месяц jun 2020

# %%
#visualization
plt.figure(figsize = (15, 5))
plt.bar(month,list1,width = 0.4)

plt.ylabel("Потребление")
plt.xlabel("Месяц")
plt.title("мин. рост потребления 2019")
plt.show()

# %%
#visualization
plt.figure(figsize = (15, 5))
plt.bar(month,list2,width = 0.4)

plt.ylabel("Потребление")
plt.xlabel("Месяц")
plt.title("мин. рост потребления 2020")
plt.show()

# %% [markdown]
# 7. Разница между потреблением во время карантина и до карантина. (Сравнить значения за март-май 2019 года и март-май 2020 года)

# %%
print(f"Полн. потребление в март-май 2019: {list1[2]+list1[3]+list1[4]}  ")
print(f"Полн. потребление в март-май 2020: {list2[2]+list2[3]+list2[4]}  ")
# Out:
# Полн. потребление в март-май 2019: 304712.4
# Полн. потребление в март-май 2020: 208813.7

# %%
diff=((list1[2]+list1[3]+list1[4])-(list2[2]+list2[3]+list2[4]))
print(f"Разница между потреблением во время карантина и до карантина: {diff}  ")
# Out:
# Разница между потреблением во время карантина и до карантина: 95898.70000000001

# %%
# visualization
num1=float((list1[2]+list1[3]+list1[4]))
num2=float((list2[2]+list2[3]+list2[4]))
list3=[]
list4=[]
list4.append(num1)
list4.append(num2)
list3.append('До карантина')
list3.append('В карантин')

# %%
plt.figure(figsize = (5, 5))
plt.bar(list3, list4, color ='maroon',
        width = 0.4)

plt.xlabel("Период")
plt.ylabel("Потребление")
plt.title("Сравнение значений за март-май 2019 года (до карантина) и март-май 2020 года (во время карантина).")
plt.show()

# %% [markdown]
# 8. Процентное изменение потребления во время карантина (по сравнению с предыдущим годом).

# %%
percent=round(((num1-num2)/num1)*100, 2)
print(f"Процентное изменение потребления во время карантина (по сравнению с предыдущим годом) составляет {percent} %")
# Out:
# Процентное изменение потребления во время карантина (по сравнению с предыдущим годом) составляет 31.47 %

# %% [markdown]
# 9. Каково самое высокое значение, достигнутое каждым штатом в любое время года в 2019 году?

# %%
table10=tk1[tk1["year"]==2019]

# %%
states=list(table10.columns)
states.remove('year')
states.remove('month')
states.remove('day')

# %%
for i in states:
    x=max(table10[i])
    print(f"Наибольшее значение в штате {i} \t в \t 2019 составило \t {x}")
# Out:
# Наибольшее значение в штате Punjab 	 в 	 2019 составило 	 286.0
# Наибольшее значение в штате Haryana 	 в 	 2019 составило 	 224.5
# Наибольшее значение в штате Rajasthan 	 в 	 2019 составило 	 278.0
# Наибольшее значение в штате Delhi 	 в 	 2019 составило 	 139.1
# Наибольшее значение в штате UP 	 в 	 2019 составило 	 469.0
# Наибольшее значение в штате Uttarakhand 	 в 	 2019 составило 	 53.2
# Наибольшее значение в штате HP 	 в 	 2019 составило 	 34.0
# Наибольшее значение в штате J&K 	 в 	 2019 составило 	 54.1
# Наибольшее значение в штате Chandigarh 	 в 	 2019 составило 	 6.8
# Наибольшее значение в штате Chhattisgarh 	 в 	 2019 составило 	 111.6
# Наибольшее значение в штате Gujarat 	 в 	 2019 составило 	 398.0
# Наибольшее значение в штате MP 	 в 	 2019 составило 	 272.3
# Наибольшее значение в штате Maharashtra 	 в 	 2019 составило 	 522.1
# Наибольшее значение в штате Goa 	 в 	 2019 составило 	 14.0
# Наибольшее значение в штате DNH 	 в 	 2019 составило 	 19.4
# ...

# %%
dict3=dict()
for i in states:
    x=max(table10[i])
    dict3.update({i:x})

table11=pd.DataFrame.from_dict(dict3,orient="index")
table11.rename(columns={0:"Наибольшее достигнутое значение"},inplace=True)
table11.head(3)
# Out:
#            Наибольшее достигнутое значение
# Punjab                               286.0
# Haryana                              224.5
# Rajasthan                            278.0

# %%
# visualization
plt.figure(figsize=(10, 10))
sns.barplot(x="Наибольшее достигнутое значение",y=table11.index,data=table11)
# Out:
# <Axes: xlabel='Наибольшее достигнутое значение'>

# %% [markdown]
# **10. Каково самое низкое значение, достигнутое каждым штатом в любое время года в 2019 году?**

# %%
for i in states:
    x=min(table10[i])
    print(f"Наименьшее значение, достигнутое в штате {i} \t в \t 2019 составило \t {x}")
# Out:
# Наименьшее значение, достигнутое в штате Punjab 	 в 	 2019 составило 	 56.1
# Наименьшее значение, достигнутое в штате Haryana 	 в 	 2019 составило 	 64.8
# Наименьшее значение, достигнутое в штате Rajasthan 	 в 	 2019 составило 	 105.8
# Наименьшее значение, достигнутое в штате Delhi 	 в 	 2019 составило 	 41.8
# Наименьшее значение, достигнутое в штате UP 	 в 	 2019 составило 	 186.8
# Наименьшее значение, достигнутое в штате Uttarakhand 	 в 	 2019 составило 	 16.8
# Наименьшее значение, достигнутое в штате HP 	 в 	 2019 составило 	 11.8
# Наименьшее значение, достигнутое в штате J&K 	 в 	 2019 составило 	 30.1
# Наименьшее значение, достигнутое в штате Chandigarh 	 в 	 2019 составило 	 2.2
# Наименьшее значение, достигнутое в штате Chhattisgarh 	 в 	 2019 составило 	 37.2
# Наименьшее значение, достигнутое в штате Gujarat 	 в 	 2019 составило 	 192.3
# Наименьшее значение, достигнутое в штате MP 	 в 	 2019 составило 	 131.8
# ...

# %%
dict4=dict()
for i in states:
    x=min(table10[i])
    dict4.update({i:x})

table12=pd.DataFrame.from_dict(dict4,orient="index")
table12.rename(columns={0:"Наименьшее достигнутое значение"},inplace=True)
table12.head(3)
# Out:
#            Наименьшее достигнутое значение
# Punjab                                56.1
# Haryana                               64.8
# Rajasthan                            105.8

# %%
# visualization
plt.figure(figsize=(10, 10))
sns.barplot(x="Наименьшее достигнутое значение",y=table12.index,data=table12)
# Out:
# <Axes: xlabel='Наименьшее достигнутое значение'>
